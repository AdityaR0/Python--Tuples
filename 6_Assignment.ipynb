# %%
Python- Tuples  Assignment Questions:
                                
        
Q1. What is a tuple in Python?

ans:)Tuples are used to store multiple items in a single variable.
Tuple is one of 4 built-in data types in Python used to store collections of data.
Tuples are immutable,they cannot be changed once they are created.

Q2. How do you create a tuple in Python? 

ans:)
Tuple1 = ()
print("empty Tuple ")
print(Tuple1)

Q3. What is the difference between a tuple and a list in Python?
Ans:)

Python Lists:)
1)List are mutable
2)Iterations are time-consuming
3)Inserting and deleting items is easier with a list.
4)Lists consume more memory.
5)Lists have several built-in methods.
6)A unexpected change or error is more likely to occur in a list.

Python Tuples:)
1)Tuples are immutable.
2)Iterations are comparatively Faster
3)Accessing the elements is best accomplished with a tuple data type.
4)Tuple consumes less than the list.
5)A tuple does not have many built-in methods because of immutability
6)In a tuple, changes and errors don't usually occur because of immutability.

Q4. Can a tuple be changed in Python?

Ans:)Tuples are unchangeable,It cannot change, add, or remove items once the tuple is created.

Q5. How do you access elements in a tuple?

Ans:)We can access tuple items by referring to the index number, inside square brackets.
Example:-
thistuple = ("apple", "banana", "cherry")
print(thistuple[1])

Q6. How do you unpack a tuple in Python?

Ans:)When we create a tuple, we normally assign values to it. This is called "packing" a tuple.
But,we are also allowed to extract the values back into variables. This is called "unpacking".
Example:-
fruits = ("apple", "banana", "cherry")

(green, yellow, red) = fruits

print(green)
print(yellow)
print(red)
